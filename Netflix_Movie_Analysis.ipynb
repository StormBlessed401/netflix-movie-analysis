# %% [markdown]
# **QUESTIONS TO ANSWER THROUGH DATA ANALYSYS:
#
# Q1: What is the most frequent genre in the dataset?
#
# Q2: What genres has highest votes ?
#
# Q3: What movie got the highest popularity ? what's its genre ?
#
# Q3: What movie got the lowest popularity ? what's its genre ?
#
# Q4: Which year has the most filmmed movies?**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('mymoviedb.csv', encoding='unicode_escape' , lineterminator='\n')
df.head()
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9827 entries, 0 to 9826
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   object
#  1   Title              9827 non-null   object
#  2   Overview           9827 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   int64
#  5   Vote_Average       9827 non-null   float64
#  6   Original_Language  9827 non-null   object
#  7   Genre              9827 non-null   object
#  8   Poster_Url         9827 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 691.1+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df['Release_Date'].dtypes)
# Out:
# object

# %%
#df['Release_Date']=pd.to_datetime(['Release_Date'])
print(df['Release_Date'].dtype)
# Out:
# object

# %%
#df['Release_Date']=df['Release_Date'].dt.year
df.head()
df.rename(columns={'Release_Date':'Release_Year'}, inplace=True)
df.head()
# Out:
#   Release_Year                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
df = pd.read_csv('mymoviedb.csv', lineterminator='\n')

# %%
print(df['Genre'])
# Out:
# 0       Action, Adventure, Science Fiction
# 1                 Crime, Mystery, Thriller
# 2                                 Thriller
# 3       Animation, Comedy, Family, Fantasy
# 4         Action, Adventure, Thriller, War
#                        ...
# 9822                          Drama, Crime
# 9823                                Horror
# 9824             Mystery, Thriller, Horror
# 9825                 Music, Drama, History
# 9826           War, Drama, Science Fiction
# Name: Genre, Length: 9827, dtype: object

# %%
df.head()
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
cols=['Overview', 'Original_Language','Poster_Url']
df.drop(cols, axis=1, inplace=True)
df.head()
# Out:
#   Release_Date                    Title  Popularity  Vote_Count  Vote_Average  \
# 0   2021-12-15  Spider-Man: No Way Home    5083.954        8940           8.3
# 1   2022-03-01               The Batman    3827.658        1151           8.1
# 2   2022-02-25                  No Exit    2618.087         122           6.3
# 3   2021-11-24                  Encanto    2402.201        5076           7.7
# 4   2021-12-22           The King's Man    1895.511        1793           7.0
#
#                                 Genre
# 0  Action, Adventure, Science Fiction
# 1            Crime, Mystery, Thriller
# 2                            Thriller
# 3  Animation, Comedy, Family, Fantasy
# 4    Action, Adventure, Thriller, War

# %%
def categorize_col(df, col, labels):
  edges=[df[col].describe()['min'],
         df[col].describe()['25%'],
         df[col].describe()['50%'],
         df[col].describe()['75%'],
         df[col].describe()['max']]
  df[col] = pd.cut(df[col], edges, labels = labels, duplicates='drop')
  return df

# %%
# define labels for edges
labels = ['not_popular', 'below_avg', 'average', 'popular']
# categorize column based on labels and edges
categorize_col(df, 'Vote_Average', labels)
# confirming changes
df['Vote_Average'].unique()
# Out:
# ['popular', 'below_avg', 'average', 'not_popular', NaN]
# Categories (4, object): ['not_popular' < 'below_avg' < 'average' < 'popular']

# %%
# exploring column
df['Vote_Average'].value_counts()
# Out:
# Vote_Average
# not_popular    2467
# popular        2450
# average        2412
# below_avg      2398
# Name: count, dtype: int64

# %%
# dropping NaNs
df.dropna(inplace = True)
# confirming
df.isna().sum()
# Out:
# Release_Date    0
# Title           0
# Popularity      0
# Vote_Count      0
# Vote_Average    0
# Genre           0
# dtype: int64

# %%
# split the strings into lists
df['Genre'] = df['Genre'].str.split(', ')
# explode the lists
df = df.explode('Genre').reset_index(drop=True)
df.head()
# Out:
#   Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0   2021-12-15  Spider-Man: No Way Home    5083.954        8940      popular
# 1   2021-12-15  Spider-Man: No Way Home    5083.954        8940      popular
# 2   2021-12-15  Spider-Man: No Way Home    5083.954        8940      popular
# 3   2022-03-01               The Batman    3827.658        1151      popular
# 4   2022-03-01               The Batman    3827.658        1151      popular
#
#              Genre
# 0           Action
# 1        Adventure
# 2  Science Fiction
# 3            Crime
# 4          Mystery

# %%
# casting column into category
df['Genre'] = df['Genre'].astype('category')
# confirming changes
df['Genre'].dtypes
# Out:
# CategoricalDtype(categories=['Action', 'Adventure', 'Animation', 'Comedy', 'Crime',
#                   'Documentary', 'Drama', 'Family', 'Fantasy', 'History',
#                   'Horror', 'Music', 'Mystery', 'Romance', 'Science Fiction',
#                   'TV Movie', 'Thriller', 'War', 'Western'],
# , ordered=False, categories_dtype=object)

# %%
df.nunique()
# Out:
# Release_Date    5846
# Title           9415
# Popularity      8088
# Vote_Count      3265
# Vote_Average       4
# Genre             19
# dtype: int64

# %%
# setting up seaborn configurations
sns.set_style('whitegrid')
# showing stats. on genre column
df['Genre'].describe()
# visualizing genre column
sns.catplot(y = 'Genre', data = df, kind = 'count',
 order = df['Genre'].value_counts().index,
 color = '#4287f5')
plt.title('genre column distribution')
plt.show()

# %% [markdown]
# Q2: What genres has highest votes ?

# %%
# visualizing vote_average column
sns.catplot(y = 'Vote_Average', data = df, kind = 'count',
 order = df['Vote_Average'].value_counts().index,
 color = '#4287f5')
plt.title('votes destribution')
plt.show()

# %% [markdown]
# Q3: What movie got the highest popularity ? what's its
# genre ?

# %%
# checking max popularity in dataset
df[df['Popularity'] == df['Popularity'].max()]
# Out:
#   Release_Date                    Title  Popularity  Vote_Count Vote_Average  \
# 0   2021-12-15  Spider-Man: No Way Home    5083.954        8940      popular
# 1   2021-12-15  Spider-Man: No Way Home    5083.954        8940      popular
# 2   2021-12-15  Spider-Man: No Way Home    5083.954        8940      popular
#
#              Genre
# 0           Action
# 1        Adventure
# 2  Science Fiction

# %% [markdown]
# Q4: What movie got the lowest popularity? what's
# its genre?

# %%
# checking max popularity in dataset
df[df['Popularity'] == df['Popularity'].min()]
# Out:
#       Release_Date                                 Title  Popularity  \
# 25546   2021-03-31  The United States vs. Billie Holiday      13.354
# 25547   2021-03-31  The United States vs. Billie Holiday      13.354
# 25548   2021-03-31  The United States vs. Billie Holiday      13.354
# 25549   1984-09-23                               Threads      13.354
# 25550   1984-09-23                               Threads      13.354
# 25551   1984-09-23                               Threads      13.354
#
#        Vote_Count Vote_Average            Genre
# 25546         152      average            Music
# 25547         152      average            Drama
# 25548         152      average          History
# 25549         186      popular              War
# 25550         186      popular            Drama
# 25551         186      popular  Science Fiction

# %% [markdown]
# Q5: Which year has the most filmmed movies?

# %%
df['Release_Date'].hist()
plt.title('Release_Date column distribution')
plt.show()

# %% [markdown]
# **Q1: What is the most frequent genre in the dataset?
# Drama genre is the most frequent genre in our dataset and has appeared more than
# 14% of the times among 19 other genres.
# Q2: What genres has highest votes ?
# we have 25.5% of our dataset with popular vote (6520 rows). Drama again gets the
# highest popularity among fans by being having more than 18.5% of movies popularities
# Q3: What movie got the highest popularity ? what's its genre ?
# Spider-Man: No Way Home has the highest popularity rate in our dataset and it has genres such as Action , Adventure and Sience Fiction .
# Q3: What movie got the lowest popularity ? what's its genre ?
# The united states, thread' has the highest lowest rate in our dataset
# and it has genres of music , drama , 'war', 'sci-fi' and history`.
# Q4: Which year has the most filmmed movies?
# year 2020 **

# %%
#Top 50 horror movies
# Filter the dataframe to include only horror movies
horror_movies_df = df[df['Genre'] == 'Horror']

# Sort the horror movies by popularity in descending order and select the top 50
top_50_horror_movies = horror_movies_df.sort_values(by='Popularity', ascending=False).head(50)

# Print the top 50 horror movies
print(top_50_horror_movies[['Title', 'Popularity', 'Vote_Average']])
# Out:
#                                        Title  Popularity Vote_Average
# 18                                    Scream    1675.161      average
# 48                   Texas Chainsaw Massacre    1312.790  not_popular
# 61            The Jack in the Box: Awakening    1096.790  not_popular
# 68    Resident Evil: Welcome to Raccoon City     881.086    below_avg
# 94                               The Hunting     761.127  not_popular
# 131                                The House     551.650      average
# 172                            The Privilege     387.924  not_popular
# 173                          Queen of Spades     387.159    below_avg
# 175                                  Antlers     380.880    below_avg
# 191                                      Two     342.661  not_popular
# 234         Paranormal Activity: Next of Kin     310.011    below_avg
# 241                               Dark Spell     308.037      average
# ...

# %%
#top 50 horror movies belonging to 'average' popularity

# Filter for 'average' popularity
average_popularity_horror_movies = horror_movies_df[horror_movies_df['Vote_Average'] == 'average']

# Sort the average popularity horror movies by Popularity in descending order and select the top 50
top_50_average_horror_movies = average_popularity_horror_movies.sort_values(by='Popularity', ascending=False).head(50)

# Print the top 50 horror movies with 'average' popularity
print(top_50_average_horror_movies[['Title', 'Popularity', 'Vote_Average']])
# Out:
#                                      Title  Popularity Vote_Average
# 18                                  Scream    1675.161      average
# 131                              The House     551.650      average
# 241                             Dark Spell     308.037      average
# 321                          Ripper Untold     257.473      average
# 402                        Halloween Kills     227.825      average
# 430                             The Unholy     214.999      average
# 483                                    Old     205.157      average
# 723                         It Chapter Two     162.984      average
# 936                              Peninsula     140.744      average
# 1010                           World War Z     133.445      average
# 1088                             El amarre     126.596      average
# 1147                             Malignant     121.064      average
# 1190  Escape Room: Tournament of Champions     116.753      average
# ...
